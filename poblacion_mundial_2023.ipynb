# %% [markdown]
# <a href="https://colab.research.google.com/github/nsanced/poblacion-mundial-2023/blob/main/poblacion_mundial_2023.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Configuración inicial y carga de datos

# %%
from google.colab import drive
#drive.mount("/content/drive")

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
filename = "/content/drive/MyDrive/Fondo Talento Digital - Es Hoy/Semana 4: Dashboards (PowerBI, Tableau) y Storytelling/Global Population 2023 - Global Population-3.csv"
df = pd.read_csv(filename)
df.head(10)
# Out:
#     # Country (or dependency) Population\n(2023) Yearly\nChange  Net\nChange  \
# 0   1                   India      1,428,627,663         0.81 %     11454490
# 1   2                   China      1,425,671,352        -0.02 %      -215985
# 2   3           United States        339,996,563         0.50 %      1706706
# 3   4               Indonesia        277,534,122         0.74 %      2032783
# 4   5                Pakistan        240,485,658         1.98 %      4660796
# 5   6                 Nigeria        223,804,632         2.41 %      5263420
# 6   7                  Brazil        216,422,446         0.52 %      1108948
# 7   8              Bangladesh        172,954,319         1.03 %      1767947
# 8   9                  Russia        144,444,359        -0.19 %      -268955
# 9  10                  Mexico        128,455,567         0.75 %       951442
#
#   Density\n(P/Km²)  Land Area\n(Km²)  Migrants\n(net)  Fert.\nRate  Med.\nAge  \
# 0              481           2973190          -486136          2.0       28.0
# 1              152           9388211          -310220          1.2       39.0
# 2               37           9147420           999700          1.7       38.0
# 3              153           1811570           -49997          2.1       30.0
# 4              312            770880          -165988          3.3       21.0
# 5              246            910770           -59996          5.1       17.0
# 6               26           8358140             6000          1.6       34.0
# 7            1,329            130170          -309977          1.9       27.0
# 8                9          16376870          -136414          1.5       39.0
# 9               66           1943950           -50239          1.8       30.0
#
#   Urban\nPop % World\nShare
# 0         36 %      17.76 %
# 1         65 %      17.72 %
# 2         83 %       4.23 %
# 3         59 %       3.45 %
# 4         35 %       2.99 %
# 5         54 %       2.78 %
# 6         88 %       2.69 %
# 7         41 %       2.15 %
# 8         75 %       1.80 %
# 9         88 %       1.60 %

# %% [markdown]
# # Renombrar columnas

# %%
df.rename(columns={"Country (or dependency)": "Country_(OrDependency)", "Population\n(2023)": "Population_2023", "Yearly\nChange": "Yearly_Change(%)", "Net\nChange": "Net_Change", \
                   "Density\n(P/Km²)": "Density_(P/Km²)", "Land Area\n(Km²)": "LandArea_(Km²)", "Migrants\n(net)": "Migrants_(net)", "Fert.\nRate": "Fert_Rate", \
                   "Med.\nAge": "Med_Age", "Urban\nPop %": "Urban_Pop(%)", "World\nShare": "World_Share(%)"}, inplace=True)
df.drop(["#"], axis=1, inplace=True)
df.head(10)
# Out:
#   Country_(OrDependency) Population_2023 Yearly_Change(%)  Net_Change  \
# 0                  India   1,428,627,663           0.81 %    11454490
# 1                  China   1,425,671,352          -0.02 %     -215985
# 2          United States     339,996,563           0.50 %     1706706
# 3              Indonesia     277,534,122           0.74 %     2032783
# 4               Pakistan     240,485,658           1.98 %     4660796
# 5                Nigeria     223,804,632           2.41 %     5263420
# 6                 Brazil     216,422,446           0.52 %     1108948
# 7             Bangladesh     172,954,319           1.03 %     1767947
# 8                 Russia     144,444,359          -0.19 %     -268955
# 9                 Mexico     128,455,567           0.75 %      951442
#
#   Density_(P/Km²)  LandArea_(Km²)  Migrants_(net)  Fert_Rate  Med_Age  \
# 0             481         2973190         -486136        2.0     28.0
# 1             152         9388211         -310220        1.2     39.0
# 2              37         9147420          999700        1.7     38.0
# 3             153         1811570          -49997        2.1     30.0
# 4             312          770880         -165988        3.3     21.0
# 5             246          910770          -59996        5.1     17.0
# 6              26         8358140            6000        1.6     34.0
# 7           1,329          130170         -309977        1.9     27.0
# 8               9        16376870         -136414        1.5     39.0
# 9              66         1943950          -50239        1.8     30.0
#
#   Urban_Pop(%) World_Share(%)
# 0         36 %        17.76 %
# 1         65 %        17.72 %
# 2         83 %         4.23 %
# 3         59 %         3.45 %
# 4         35 %         2.99 %
# 5         54 %         2.78 %
# 6         88 %         2.69 %
# 7         41 %         2.15 %
# 8         75 %         1.80 %
# 9         88 %         1.60 %

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 11 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Country_(OrDependency)  234 non-null    object
#  1   Population_2023         234 non-null    object
#  2   Yearly_Change(%)        234 non-null    object
#  3   Net_Change              234 non-null    int64
#  4   Density_(P/Km²)         234 non-null    object
#  5   LandArea_(Km²)          234 non-null    int64
#  6   Migrants_(net)          234 non-null    int64
#  7   Fert_Rate               233 non-null    float64
#  8   Med_Age                 233 non-null    float64
#  9   Urban_Pop(%)            234 non-null    object
#  10  World_Share(%)          234 non-null    object
# dtypes: float64(2), int64(3), object(6)
# memory usage: 20.2+ KB

# %% [markdown]
# # Filtrado de filas con valores faltantes en tasas de fertilidad y edad media

# %%
FertNan_filter = df["Fert_Rate"].isna()
AgeNan_filter = df["Med_Age"].isna()
df.loc[FertNan_filter | AgeNan_filter, :]
# Out:
#     Country_(OrDependency) Population_2023 Yearly_Change(%)  Net_Change  \
# 233               Holy See             518           1.57 %           8
#
#     Density_(P/Km²)  LandArea_(Km²)  Migrants_(net)  Fert_Rate  Med_Age  \
# 233           1,295               0               0        NaN      NaN
#
#     Urban_Pop(%) World_Share(%)
# 233         N.A.         0.00 %

# %% [markdown]
# # Actualización de datos para el Estado de la Ciudad del Vaticano (Santa Sede)

# %%
df1=df
HolySee_filter = df1["Country_(OrDependency)"] == "Holy See"
df1.loc[HolySee_filter, "Fert_Rate"] = 1.0
df1.loc[HolySee_filter, "Med_Age"] = 57
df1.loc[HolySee_filter, :]
# Out:
#     Country_(OrDependency) Population_2023 Yearly_Change(%)  Net_Change  \
# 233               Holy See             518           1.57 %           8
#
#     Density_(P/Km²)  LandArea_(Km²)  Migrants_(net)  Fert_Rate  Med_Age  \
# 233           1,295               0               0        1.0     57.0
#
#     Urban_Pop(%) World_Share(%)
# 233         N.A.         0.00 %

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 11 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Country_(OrDependency)  234 non-null    object
#  1   Population_2023         234 non-null    object
#  2   Yearly_Change(%)        234 non-null    object
#  3   Net_Change              234 non-null    int64
#  4   Density_(P/Km²)         234 non-null    object
#  5   LandArea_(Km²)          234 non-null    int64
#  6   Migrants_(net)          234 non-null    int64
#  7   Fert_Rate               234 non-null    float64
#  8   Med_Age                 234 non-null    float64
#  9   Urban_Pop(%)            234 non-null    object
#  10  World_Share(%)          234 non-null    object
# dtypes: float64(2), int64(3), object(6)
# memory usage: 20.2+ KB

# %% [markdown]
# # Eliminación de comas en la población mundial para el año 2023 y Eliminación de porcentajes en el cambio anual

# %%
def delete_comma(column):
  try:
    value = column.replace(",", "")
    return int(value)
  except:
    return value

df1["Population_2023"] = df1.apply(lambda row: delete_comma(row["Population_2023"]), axis=1)

# %%
def delete_percentage(column):
  try:
    value = column.replace("%", "")
    value = value.strip("% \t\n\r\x0b\x0c")
    return float(value)
  except:
    return value

df1["Yearly_Change(%)"] = df1.apply(lambda row: delete_percentage(row["Yearly_Change(%)"]), axis=1)

# %%
df1["Density_(P/Km²)"] = df1.apply(lambda row: delete_comma(row["Density_(P/Km²)"]), axis=1)
df1["Urban_Pop(%)"] = df1.apply(lambda row: delete_percentage(row["Urban_Pop(%)"]), axis=1)
df1["World_Share(%)"] = df1.apply(lambda row: delete_percentage(row["World_Share(%)"]), axis=1)
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 11 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Country_(OrDependency)  234 non-null    object
#  1   Population_2023         234 non-null    int64
#  2   Yearly_Change(%)        234 non-null    float64
#  3   Net_Change              234 non-null    int64
#  4   Density_(P/Km²)         234 non-null    int64
#  5   LandArea_(Km²)          234 non-null    int64
#  6   Migrants_(net)          234 non-null    int64
#  7   Fert_Rate               234 non-null    float64
#  8   Med_Age                 234 non-null    float64
#  9   Urban_Pop(%)            234 non-null    object
#  10  World_Share(%)          234 non-null    float64
# dtypes: float64(4), int64(5), object(2)
# memory usage: 20.2+ KB

# %% [markdown]
# # Filtrado de filas con valores "N.A." en la población urbana

# %%
na_filter = df1["Urban_Pop(%)"] == "N.A."
df1.loc[na_filter, :]
# Out:
#        Country_(OrDependency)  Population_2023  Yearly_Change(%)  Net_Change  \
# 51                  Venezuela         28838499              1.90      536803
# 103                 Hong Kong          7491609              0.04        2744
# 113                 Singapore          6014723              0.65       39034
# 126                      Oman          4644384              1.49       68086
# 128                    Kuwait          4310108              0.97       41235
# 135               Puerto Rico          3260314              0.24        7907
# 142                     Qatar          2716391              0.79       21269
# 153                   Bahrain          1485509              0.90       13276
# 178                Guadeloupe           395839              0.02          87
# 198       U.S. Virgin Islands            98750             -0.72        -715
# 207  Northern Mariana Islands            49796              0.49         245
# 211            American Samoa            43914             -0.81        -359
# 212          Marshall Islands            41996              1.03         427
# 214                    Monaco            36297             -0.47        -172
# 216                 Gibraltar            32688              0.12          39
# 220                     Palau            18058              0.02           3
# 227   Saint Pierre & Miquelon             5840             -0.38         -22
# 233                  Holy See              518              1.57           8
#
#      Density_(P/Km²)  LandArea_(Km²)  Migrants_(net)  Fert_Rate  Med_Age  \
# 51                33          882050          321106        2.2     28.0
# 103             7135            1050           19999        0.8     46.0
# 113             8592             700           26998        1.0     43.0
# 126               15          309500               0        2.5     29.0
# 128              242           17820           11999        2.1     40.0
# 135              368            8870           19835        1.3     44.0
# 142              234           11610               0        1.8     34.0
# 153             1955             760               0        1.8     34.0
# 178              234            1690            -800        2.0     42.0
# 198              282             350            -450        2.1     43.0
# 207              108             460             -50        2.1     38.0
# 211              220             200            -790        2.2     29.0
# 212              233             180               0        2.6     26.0
# 214            24360               1             200        2.1     54.0
# 216             3269              10             -24        1.8     42.0
# 220               39             460             -20        2.3     36.0
# 227               25             230               0        1.6     44.0
# 233             1295               0               0        1.0     57.0
#
#     Urban_Pop(%)  World_Share(%)
# 51          N.A.            0.36
# 103         N.A.            0.09
# 113         N.A.            0.07
# 126         N.A.            0.06
# 128         N.A.            0.05
# 135         N.A.            0.04
# 142         N.A.            0.03
# 153         N.A.            0.02
# 178         N.A.            0.00
# 198         N.A.            0.00
# 207         N.A.            0.00
# 211         N.A.            0.00
# 212         N.A.            0.00
# 214         N.A.            0.00
# 216         N.A.            0.00
# 220         N.A.            0.00
# 227         N.A.            0.00
# 233         N.A.            0.00

# %% [markdown]
# # Actualización de la población urbana en países faltantes y conversión de tipos de datos

# %%
df1.loc[df1["Country_(OrDependency)"]=="Venezuela", "Urban_Pop(%)"] = 88.0
df1.loc[df1["Country_(OrDependency)"]=="Hong Kong", "Urban_Pop(%)"] = 100.0
df1.loc[df1["Country_(OrDependency)"]=="Singapore", "Urban_Pop(%)"] = 100.0
df1.loc[df1["Country_(OrDependency)"]=="Oman", "Urban_Pop(%)"] = 88.0
df1.loc[df1["Country_(OrDependency)"]=="Kuwait", "Urban_Pop(%)"] = 100.0
df1.loc[df1["Country_(OrDependency)"]=="Puerto Rico", "Urban_Pop(%)"] = 94.0
df1.loc[df1["Country_(OrDependency)"]=="Qatar", "Urban_Pop(%)"] = 99.0
df1.loc[df1["Country_(OrDependency)"]=="Bahrain", "Urban_Pop(%)"] = 90.0
df1.loc[df1["Country_(OrDependency)"]=="U.S. Virgin Islands", "Urban_Pop(%)"] = 96.0
df1.loc[df1["Country_(OrDependency)"]=="Northern Mariana Islands", "Urban_Pop(%)"] = 92.0
df1.loc[df1["Country_(OrDependency)"]=="American Samoa", "Urban_Pop(%)"] = 87.0
df1.loc[df1["Country_(OrDependency)"]=="Marshall Islands", "Urban_Pop(%)"] = 79.0
df1.loc[df1["Country_(OrDependency)"]=="Monaco", "Urban_Pop(%)"] = 100.0
df1.loc[df1["Country_(OrDependency)"]=="Gibraltar", "Urban_Pop(%)"] = 100.0
df1.loc[df1["Country_(OrDependency)"]=="Palau", "Urban_Pop(%)"] = 82.0
df1.loc[df1["Country_(OrDependency)"]=="Saint Pierre & Miquelon", "Urban_Pop(%)"] = 90.0
df1.loc[df1["Country_(OrDependency)"]=="Holy See", "Urban_Pop(%)"] = 100.0
df1.loc[df1["Country_(OrDependency)"]=="Guadeloupe", "Urban_Pop(%)"] = 99.0
df1["Urban_Pop(%)"] = df1["Urban_Pop(%)"].astype(float)
df1["Med_Age"] = df1["Med_Age"].astype(int)
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 11 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Country_(OrDependency)  234 non-null    object
#  1   Population_2023         234 non-null    int64
#  2   Yearly_Change(%)        234 non-null    float64
#  3   Net_Change              234 non-null    int64
#  4   Density_(P/Km²)         234 non-null    int64
#  5   LandArea_(Km²)          234 non-null    int64
#  6   Migrants_(net)          234 non-null    int64
#  7   Fert_Rate               234 non-null    float64
#  8   Med_Age                 234 non-null    int64
#  9   Urban_Pop(%)            234 non-null    float64
#  10  World_Share(%)          234 non-null    float64
# dtypes: float64(4), int64(6), object(1)
# memory usage: 20.2+ KB

# %% [markdown]
# # Preparación de datos para visualización

# %%
df2 = df1.loc[0:19, ["Country_(OrDependency)", "Population_2023"]]
df2["Population_2023"] = ((df2["Population_2023"]/1000000).round()).astype(int)
countries = np.array(df2["Country_(OrDependency)"])
population_mill = np.array(df2["Population_2023"])

# %% [markdown]
# # Gráfico de donut de las 20 poblaciones más grandes del mundo

# %%
fig, ax = plt.subplots(figsize=(10, 10));
ax.pie(population_mill, labels=countries, startangle=120, counterclock=False);
ax.set_title("Top 20 Population in the World", fontsize=15)
ax.legend(loc="center left", bbox_to_anchor=(-0.3, 0.5), title="Country Name")
centre_circle = plt.Circle((0, 0), 0.70, fc='white')
fig.gca().add_artist(centre_circle)
plt.show()
